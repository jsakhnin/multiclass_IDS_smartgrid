# %%
import pandas as pd
from scipy.io import arff
import numpy as np
from sklearn.model_selection import train_test_split
import erlc as e
import dataPipeline as dp
from sklearn.metrics import f1_score, accuracy_score, matthews_corrcoef

# %% [markdown]
# # 1.0 Data

# %%
dataPipeline = dp.DataPipeline()
data = dataPipeline.loadData()
X, y = dataPipeline.dataProc(data)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# Loading dataset #1
# Loading dataset #2
# Loading dataset #3
# Loading dataset #4
# Loading dataset #5
# Loading dataset #6
# Loading dataset #7
# Loading dataset #8
# Loading dataset #9
# Loading dataset #10
# Loading dataset #11
# Loading dataset #12
# Loading dataset #13
# Loading dataset #14
# Loading dataset #15
# Finished Loading. Final Size = (78377, 129)

# %% [markdown]
# # 2.0 Model
# ## 2.1 Initializing and Training

# %%
model = e.ERLC()

# %%
model.fit(X_train, y_train)
# Out:
# Building ERLC model
# Building autoencoder
# Epoch 1/500
# 196/196 [==============================] - 6s 32ms/step - loss: 0.0376 - mse: 0.0376 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 2/500
# 196/196 [==============================] - 5s 25ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 3/500
# 196/196 [==============================] - 4s 22ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 4/500
# 196/196 [==============================] - 4s 21ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 5/500
# 196/196 [==============================] - 4s 19ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 6/500
# 196/196 [==============================] - 6s 31ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 7/500
# ...

# %%
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
print("Accuracy = {}, F1-score = {}, MCC = {}".format(acc, f1, mcc))
# Out:
# Accuracy = 0.9411201837203368, F1-score = 0.9410678280715226, MCC = 0.939161224483063

# %% [markdown]
# Below we save the model for later use. The default directory is "saved_model" in the project folder. But this can be changed as an input to save_model called "save_path".

# %%
model.save_model(save_path = 'saved_model/')

# %% [markdown]
# ## 2.2 Loading Saved Model

# %%
loaded_model = e.ERLC()
loaded_model.load_model(save_path = 'saved_model/')

# %%
y_pred = loaded_model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
print("Accuracy = {}, F1-score = {}, MCC = {}".format(acc, f1, mcc))
